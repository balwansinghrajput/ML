# %% [markdown]
# basic understanding ML

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/ml/placement_dataset.csv")
# print(dataset)
headdata = df.head()
print(headdata)
infodata = df.info()
print(infodata)
arr = np.array([1,2,3,4,5,6,7])
print(arr)
# Out:
#     iq  cgpa  placement
# 0  107  7.43          0
# 1   98  7.67          0
# 2  110  8.30          1
# 3  123  8.26          1
# 4   96  5.35          0
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   iq         200 non-null    int64
#  1   cgpa       200 non-null    float64
#  2   placement  200 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 4.8 KB
# None
# [1 2 3 4 5 6 7]

# %%
plt.scatter(df["cgpa"] , df["iq"] , c=df["placement"])

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]
# s = x.shape
# print(y)

# %%
from sklearn.model_selection import  train_test_split

x_train , X_test, y_train , Y_test = train_test_split(x , y , test_size=0.1)

# print(x_train , y_train , Y_test , X_test )

# %%
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)

print(x_train)
# Out:
# [[ 1.74197213 -0.23399813]
#  [ 0.0159814   0.62191862]
#  [ 2.10155353  0.14260524]
#  [ 0.59131164  0.28811109]
#  [-0.12785117 -0.13984729]
#  [-0.77509769  0.33090692]
#  [ 1.67005585  1.54630871]
#  [-1.99767446  0.58768195]
#  [-0.48743257  0.56200445]
#  [-0.91893025  0.52776778]
#  [ 1.16664189 -1.63770159]
#  [ 0.95089304  0.45073527]
#  [-0.19976745  0.0227769 ]
#  [ 0.3755628   2.12833209]
#  [-0.12785117 -1.99718663]
#  [ 0.80706048 -0.92729069]
#  [ 0.0159814   1.11835033]
#  [-1.4942605  -1.31245323]
#  [ 0.0159814   1.84587957]
#  [ 0.3755628  -0.30247147]
#  [ 2.10155353 -0.09705145]
#  [ 0.3755628  -0.09705145]
#  [ 0.95089304  0.3908211 ]
#  [ 0.59131164 -0.61916067]
#  [ 0.15981396  0.12548691]
#  [ 0.15981396  0.76742447]
#  [ 0.3755628  -0.56780566]
#  [-0.63126513  0.05701357]
#  [-1.4942605  -0.79034401]
#  [ 0.3755628   0.23675608]
#  [ 0.15981396  0.56200445]
#  [ 0.7351442  -0.94440903]
#  [ 0.44747908  1.73461039]
#  [ 0.15981396  0.62191862]
#  [-1.42234422 -1.7404116 ]
#  [ 0.66322792 -0.81602152]
#  [-1.42234422 -0.92729069]
#  [-1.20659538 -0.39662231]
#  [-0.34360001 -0.65339733]
#  [-1.99767446 -0.30247147]
#  [ 0.0159814  -0.28535313]
#  [ 0.0159814   1.40936203]
#  [-0.27168373  0.79310197]
#  [ 0.66322792 -0.72187067]
#  [ 0.95089304  0.15116441]
#  [ 0.44747908  1.40080286]
#  [-0.34360001  0.86157531]
#  [ 0.30364652  1.13546867]
#  [ 0.59131164 -0.77322568]
#  [ 1.16664189  0.71606946]
#  [-2.06959074 -1.08991488]
#  [ 0.51939536 -0.55924649]
#  [-1.35042794 -1.52643242]
#  [ 1.74197213 -1.55210992]
#  [ 1.31047445  0.25387442]
#  [-1.06276281 -0.00290061]
#  [ 1.52622329  0.16828274]
#  [-1.63809306  0.16828274]
#  [ 0.3755628   0.84445697]
#  [-1.56617678 -0.08849228]
#  [ 1.09472561 -0.23399813]
#  [-1.20659538 -1.13271071]
#  [-2.06959074 -0.47365482]
#  [-0.70318141 -1.10703321]
#  [-0.84701397 -0.05425561]
#  [ 1.81388841  0.45073527]
#  [-0.84701397 -0.69619317]
#  [ 0.51939536 -1.18406572]
#  [ 0.59131164  0.27099275]
#  [-1.42234422  2.06841792]
#  [ 2.46113494 -1.32957157]
#  [-0.48743257  0.7331878 ]
#  [ 0.23173024  1.04131783]
#  [ 0.15981396 -1.0043232 ]
#  [ 0.44747908  0.90437115]
#  [ 0.15981396 -0.19976146]
#  [-0.19976745  0.62191862]
#  [-1.78192562 -0.40518148]
#  [ 0.66322792  2.48781713]
#  [ 0.7351442  -1.11559238]
#  [ 0.08789768  0.7588653 ]
#  [-1.13467909 -0.01145977]
#  [ 0.44747908  0.52776778]
#  [ 0.44747908  0.59624112]
#  [ 2.10155353 -0.06281478]
#  [ 1.31047445 -0.19120229]
#  [-1.27851166 -1.56922825]
#  [ 0.95089304  0.34802526]
#  [ 0.30364652 -0.2425573 ]
#  [-0.55934885 -0.83313985]
#  [-1.42234422  0.00565856]
#  [ 0.7351442   0.98140365]
#  [-0.99084653  1.10979117]
#  [-0.41551629  1.08411366]
#  [ 0.15981396 -0.2939123 ]
#  [-1.27851166  1.80308373]
#  [ 1.74197213 -0.07137395]
#  [ 0.95089304  0.0227769 ]]

# %%
X_test = scaler.fit_transform(X_test)
print(X_test)
# Out:
# [[ 3.11925147e+00 -1.29421964e+00]
#  [-5.55111512e-18  1.85792419e+00]
#  [-6.93166993e-01 -1.72562618e-02]
#  [-1.73291748e-01 -1.99597428e+00]
#  [ 5.19875245e-01 -3.62381498e-01]
#  [ 8.66458742e-01 -8.57061004e-01]
#  [-3.46583497e-01 -8.62813091e-02]
#  [-1.12639636e+00  8.68565178e-01]
#  [-6.06521119e-01  5.23439942e-01]
#  [-1.47297986e+00  5.11935767e-01]
#  [ 6.93166993e-01  5.00431593e-01]
#  [ 5.19875245e-01  2.87604364e-02]
#  [-8.66458742e-02  1.13316119e+00]
#  [-5.55111512e-18 -5.00431593e-01]
#  [-1.73291748e-01 -9.95111098e-01]
#  [-7.79812867e-01 -1.00661527e+00]
#  [-8.66458742e-02  5.80960814e-01]
#  [ 7.79812867e-01  7.76531782e-01]
#  [-1.55962573e+00  1.57031983e+00]
#  [ 6.06521119e-01 -1.23669876e+00]]

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model traning

# %%
clf.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
print(Y_test)
# Out:
# 179    1
# 151    1
# 80     0
# 192    0
# 119    1
# 91     1
# 78     1
# 15     0
# 42     0
# 171    1
# 191    1
# 185    1
# 12     0
# 17     1
# 107    0
# 77     0
# 108    1
# 164    1
# 56     1
# 175    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test , y_pred )
# Out:
# 0.6

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train , y_train.values , clf=clf , legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf , open('model.pkl' , 'wb'))
